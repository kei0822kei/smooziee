# %%
##### setting
### set filename you want to analysis
filepath = None

if filepath == None:
    import os
    import smooziee
    filepath = os.path.join(os.path.dirname(smooziee.__file__), 'data', 'PbTe_sq_GX711_p0p25_RT_4')
    
filename = os.path.basename(filepath)

# %%
##### import
import smooziee.module.fitting as sm_fit
import imp
imp.reload(sm_fit)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
##### read data from filename
data_df = pd.read_csv(filepath, sep='\s+')
x_arr = np.array(data_df.meV)
y_arr = np.array(data_df.y_unitpk)

# %%
##### make object
processor = sm_fit.Processor(x_arr, y_arr, name=filename)

# %%
##### find peak automatically
processor.find_peak(order=5, notice=True)


### make figure
fig = plt.figure()
ax = fig.add_subplot(111)
processor.plot(ax)
# Out:
# found 5 peaks

# %%
##### add peak by hand

### test mode
# processor.add_peak(idx=55, run_mode='test')

### add mode
processor.add_peak(idx=55, run_mode='add')
processor.add_peak(idx=15, run_mode='add')

### make figure
fig = plt.figure()
ax = fig.add_subplot(111)
processor.plot(ax)

# %%
##### remove peak by hand
# processor.remove_peak(21)
# print(processor.peak_idx_lst)

# %%
##### find peak pair automatically
processor.find_peak_pair(threshold=10, notice=True)
print(processor.peak_pair_idx_lst)

### make figure
fig = plt.figure()
ax = fig.add_subplot(111)
processor.plot(ax)
# Out:
# found 3 pair
# [[7, 47], [15, 36], [21, 28]]

# %%
##### find peak pair by hand
print("current peak_idx_lst")
print(processor.peak_idx_lst)
print("")
print("initial peak_pair_idx_lst")
print(processor.peak_pair_idx_lst)

### test
# processor.revise_peak_pair([[7,36], [15,28]], run_mode='test')

### revise
processor.revise_peak_pair([[7,36], [15,28]], run_mode='revise')

print("")
print("revised peak_pair_idx_lst")
print(processor.peak_pair_idx_lst)

### make figure
fig = plt.figure()
ax = fig.add_subplot(111)
processor.plot(ax)
# Out:
# current peak_idx_lst
# [7, 15, 21, 28, 36, 47, 55]
#
# initial peak_pair_idx_lst
# [[7, 47], [15, 36], [21, 28]]
#
# revised peak_pair_idx_lst
# [[7, 36], [15, 28]]

# %%
##### initial fit
processor.initial_fit(idx_range=3, notice=True)


### make figure
fig = plt.figure()
ax = fig.add_subplot(111)
processor.plot(ax)
# Out:
# make initial fitting
# index 55 could not make curve_fit

# %%
##### revise best param by hand
"""
processor.revise_best_param(arg_lst)
arg_lst = [peak_idx, var_num, addition or subtraction]
    var_num => 0: peak_y
               1: peak_x
               2: width
"""

### peak_y
# processor.revise_best_param([[1,2,3], 0, 0.1])

### peak_x
processor.revise_best_param([3, 1, -0.1])

### width
# processor.revise_best_param([[1] ,2, -0.1])

### make figure
fig = plt.figure()
ax = fig.add_subplot(111)
processor.plot(ax)
print(processor.best_param_lst)
# Out:
# [[0.7495963876836338, -7.232401808143172, 1.4310239002844756], [0.3301832193377876, -2.7191986631694096, 1.8090668642566188], [0.30935097242097565, -9.435639262282436e-05, 1.5407600104336776], [0.3710813901603396, 3.5322744712483396, 1.8090668642566188], [0.9857898409825715, 7.781324170328765, 1.4310239002844756], [0.5532509894276989, 13.096173017846375, 2.118452894580713], [0.2282, 17.0, 1.0]]

# %%
processor.set_function()
processor.fit(iteration=5, log=False)
# Out:
# iteration number: 1
# Warning: Maximum number of function evaluations has been exceeded.
# iteration number: 2
# Warning: Maximum number of function evaluations has been exceeded.
# iteration number: 3
# Warning: Maximum number of function evaluations has been exceeded.
# iteration number: 4
# Warning: Maximum number of function evaluations has been exceeded.
# iteration number: 5
# Warning: Maximum number of function evaluations has been exceeded.

# %%
processor.set_center(2)
print(processor.center_move)
print(processor.center_peak)

fig = plt.figure()
ax = fig.add_subplot(111)
processor.plot(ax)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-121d677a6994> in <module>()
# ----> 1 imp.reload(processor)
#       2 # processor.set_center(2)
#       3 # print(processor.center_move)
#       4 # print(processor.center_peak)
#       5 #
#
# ~/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/imp.py in reload(module)
#     313
#     314     """
# --> 315     return importlib.reload(module)
#     316
#     317
#
# ~/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/importlib/__init__.py in reload(module)
#     137     """
#     138     if not module or not isinstance(module, types.ModuleType):
# --> 139         raise TypeError("reload() argument must be a module")
#     140     try:
#     141         name = module.__spec__.name
#
# TypeError: reload() argument must be a module

# %%
##### save results
### make hdf5 file and figure
savefile = os.path.basename(filename)
processor.save(savefile=savefile)
processor.save(savefile='hoge')

# %%
ls
# Out:
# PbTe_sq_GX711_p0p25_RT_4.hdf5  hoge.hdf5
# PbTe_sq_GX711_p0p25_RT_4.png   template.ipynb
# develop.ipynb

# %%
##### reload from hdf5 file
new_processor = sm_fit.Processor(x_arr, y_arr)
new_processor.load(savefile+'.hdf5')

### make figure
fig = plt.figure()
ax = fig.add_subplot(111)
new_processor.plot(ax)
