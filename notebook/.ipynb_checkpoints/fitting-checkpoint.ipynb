# %%
##### setting
### set filename you want to analysis
pkldata =

# %%
##### import
from smooziee import fitting
from smooziee import peak_search
import os
import imp
import matplotlib.pyplot as plt
imp.reload(fitting)
imp.reload(peak_search)
# Out:
# <module 'smooziee.peak_search' from '/Users/keiyu/Github/smooziee/smooziee/peak_search.py'>

# %%
### show peaksearch result
peak_num = fitting.result_peaksearch(pkldata, return_peak_num=True)
# Out:
# the number of peaks: 11

# %%
### make Fitting class object
fitter = fitting.Fitting(pkldata, ['lorentzian' for i in range(peak_num)])

# %%
print(fitter.i_degenerates)
print(fitter.i_peakpairs)
fitter.params.pretty_print()
# Out:
# [[2, 3], [5, 6]]
# [[1, 7], [2, 5]]
# Name              Value      Min      Max   Stderr     Vary     Expr Brute_Step
# l0_amplitude          1     0.05      inf     None     True     None     None
# l0_center         -10.5      -11      -10     None     True     None     None
# l0_fwhm               2     -inf      inf     None    False 2.0000000*l0_sigma     None
# l0_height        0.3183     -inf      inf     None    False 0.3183099*l0_amplitude/max(1.e-15, l0_sigma)     None
# l0_sigma              1     0.05        2     None     True     None     None
# l10_amplitude         1     0.05      inf     None     True     None     None
# l10_center         12.5       12       13     None     True     None     None
# l10_fwhm              2     -inf      inf     None    False 2.0000000*l10_sigma     None
# l10_height       0.3183     -inf      inf     None    False 0.3183099*l10_amplitude/max(1.e-15, l10_sigma)     None
# l10_sigma             1     0.05        2     None     True     None     None
# l1_amplitude          1     0.05      inf     None     True     None     None
# l1_center            -7     -7.5     -6.5     None     True     None     None
# l1_fwhm               2     -inf      inf     None    False 2.0000000*l1_sigma     None
# l1_height        0.3183     -inf      inf     None    False 0.3183099*l1_amplitude/max(1.e-15, l1_sigma)     None
# l1_sigma              1     0.05        2     None     True     None     None
# l2_amplitude          1     0.05      inf     None     True     None     None
# l2_center            -5     -5.5     -4.5     None     True     None     None
# l2_fwhm               2     -inf      inf     None    False 2.0000000*l2_sigma     None
# l2_height        0.3183     -inf      inf     None    False 0.3183099*l2_amplitude/max(1.e-15, l2_sigma)     None
# l2_sigma              1     0.05        2     None     True     None     None
# l3_amplitude          1     0.05      inf     None    False l2_amplitude     None
# l3_center            -5     -5.5     -4.5     None    False l2_center     None
# l3_fwhm               2     -inf      inf     None    False 2.0000000*l3_sigma     None
# l3_height        0.3183     -inf      inf     None    False 0.3183099*l3_amplitude/max(1.e-15, l3_sigma)     None
# l3_sigma              1     0.05        2     None    False l2_sigma     None
# l4_amplitude          1     0.05      inf     None     True     None     None
# l4_center          -1.5       -2       -1     None     True     None     None
# l4_fwhm               2     -inf      inf     None    False 2.0000000*l4_sigma     None
# l4_height        0.3183     -inf      inf     None    False 0.3183099*l4_amplitude/max(1.e-15, l4_sigma)     None
# l4_sigma              1     0.05        2     None     True     None     None
# l5_amplitude          1     0.05      inf     None     True     None     None
# l5_center             2      1.5      2.5     None     True     None     None
# l5_fwhm               2     -inf      inf     None    False 2.0000000*l5_sigma     None
# l5_height        0.3183     -inf      inf     None    False 0.3183099*l5_amplitude/max(1.e-15, l5_sigma)     None
# l5_sigma              1     0.05        2     None    False l2_sigma     None
# l6_amplitude          1     0.05      inf     None    False l5_amplitude     None
# l6_center             2      1.5      2.5     None    False l5_center     None
# l6_fwhm               2     -inf      inf     None    False 2.0000000*l6_sigma     None
# l6_height        0.3183     -inf      inf     None    False 0.3183099*l6_amplitude/max(1.e-15, l6_sigma)     None
# l6_sigma              1     0.05        2     None    False l5_sigma     None
# l7_amplitude          1     0.05      inf     None     True     None     None
# l7_center           4.5        4        5     None     True     None     None
# l7_fwhm               2     -inf      inf     None    False 2.0000000*l7_sigma     None
# l7_height        0.3183     -inf      inf     None    False 0.3183099*l7_amplitude/max(1.e-15, l7_sigma)     None
# l7_sigma              1     0.05        2     None    False l1_sigma     None
# l8_amplitude          1     0.05      inf     None     True     None     None
# l8_center           7.5        7        8     None     True     None     None
# l8_fwhm               2     -inf      inf     None    False 2.0000000*l8_sigma     None
# l8_height        0.3183     -inf      inf     None    False 0.3183099*l8_amplitude/max(1.e-15, l8_sigma)     None
# l8_sigma              1     0.05        2     None     True     None     None
# l9_amplitude          1     0.05      inf     None     True     None     None
# l9_center            10      9.5     10.5     None     True     None     None
# l9_fwhm               2     -inf      inf     None    False 2.0000000*l9_sigma     None
# l9_height        0.3183     -inf      inf     None    False 0.3183099*l9_amplitude/max(1.e-15, l9_sigma)     None
# l9_sigma              1     0.05        2     None     True     None     None

# %%
### set parameters to optimize
## i_peaks -- peak index you want to set
## param_names -- 'amplitude', 'sigma', 'center'
## vary -- True => optimize, False => not optimize
fitter.set_params_vary(i_peaks=list(range(peak_num)), param_names=['center'], vary=False)

# %%
### parameters
fitter.params.pretty_print()
# Out:
# Name              Value      Min      Max   Stderr     Vary     Expr Brute_Step
# l0_amplitude          1     0.05      inf     None     True     None     None
# l0_center         -10.5      -11      -10     None    False     None     None
# l0_fwhm               2     -inf      inf     None    False 2.0000000*l0_sigma     None
# l0_height        0.3183     -inf      inf     None    False 0.3183099*l0_amplitude/max(1.e-15, l0_sigma)     None
# l0_sigma              1     0.05        2     None     True     None     None
# l10_amplitude         1     0.05      inf     None     True     None     None
# l10_center         12.5       12       13     None    False     None     None
# l10_fwhm              2     -inf      inf     None    False 2.0000000*l10_sigma     None
# l10_height       0.3183     -inf      inf     None    False 0.3183099*l10_amplitude/max(1.e-15, l10_sigma)     None
# l10_sigma             1     0.05        2     None     True     None     None
# l1_amplitude          1     0.05      inf     None     True     None     None
# l1_center            -7     -7.5     -6.5     None    False     None     None
# l1_fwhm               2     -inf      inf     None    False 2.0000000*l1_sigma     None
# l1_height        0.3183     -inf      inf     None    False 0.3183099*l1_amplitude/max(1.e-15, l1_sigma)     None
# l1_sigma              1     0.05        2     None     True     None     None
# l2_amplitude          1     0.05      inf     None     True     None     None
# l2_center            -5     -5.5     -4.5     None    False     None     None
# l2_fwhm               2     -inf      inf     None    False 2.0000000*l2_sigma     None
# l2_height        0.3183     -inf      inf     None    False 0.3183099*l2_amplitude/max(1.e-15, l2_sigma)     None
# l2_sigma              1     0.05        2     None     True     None     None
# l3_amplitude          1     0.05      inf     None    False l2_amplitude     None
# l3_center            -5     -5.5     -4.5     None    False l2_center     None
# l3_fwhm               2     -inf      inf     None    False 2.0000000*l3_sigma     None
# l3_height        0.3183     -inf      inf     None    False 0.3183099*l3_amplitude/max(1.e-15, l3_sigma)     None
# l3_sigma              1     0.05        2     None    False l2_sigma     None
# l4_amplitude          1     0.05      inf     None     True     None     None
# l4_center          -1.5       -2       -1     None    False     None     None
# l4_fwhm               2     -inf      inf     None    False 2.0000000*l4_sigma     None
# l4_height        0.3183     -inf      inf     None    False 0.3183099*l4_amplitude/max(1.e-15, l4_sigma)     None
# l4_sigma              1     0.05        2     None     True     None     None
# l5_amplitude          1     0.05      inf     None     True     None     None
# l5_center             2      1.5      2.5     None    False     None     None
# l5_fwhm               2     -inf      inf     None    False 2.0000000*l5_sigma     None
# l5_height        0.3183     -inf      inf     None    False 0.3183099*l5_amplitude/max(1.e-15, l5_sigma)     None
# l5_sigma              1     0.05        2     None    False l2_sigma     None
# l6_amplitude          1     0.05      inf     None    False l5_amplitude     None
# l6_center             2      1.5      2.5     None    False l5_center     None
# l6_fwhm               2     -inf      inf     None    False 2.0000000*l6_sigma     None
# l6_height        0.3183     -inf      inf     None    False 0.3183099*l6_amplitude/max(1.e-15, l6_sigma)     None
# l6_sigma              1     0.05        2     None    False l5_sigma     None
# l7_amplitude          1     0.05      inf     None     True     None     None
# l7_center           4.5        4        5     None    False     None     None
# l7_fwhm               2     -inf      inf     None    False 2.0000000*l7_sigma     None
# l7_height        0.3183     -inf      inf     None    False 0.3183099*l7_amplitude/max(1.e-15, l7_sigma)     None
# l7_sigma              1     0.05        2     None    False l1_sigma     None
# l8_amplitude          1     0.05      inf     None     True     None     None
# l8_center           7.5        7        8     None    False     None     None
# l8_fwhm               2     -inf      inf     None    False 2.0000000*l8_sigma     None
# l8_height        0.3183     -inf      inf     None    False 0.3183099*l8_amplitude/max(1.e-15, l8_sigma)     None
# l8_sigma              1     0.05        2     None     True     None     None
# l9_amplitude          1     0.05      inf     None     True     None     None
# l9_center            10      9.5     10.5     None    False     None     None
# l9_fwhm               2     -inf      inf     None    False 2.0000000*l9_sigma     None
# l9_height        0.3183     -inf      inf     None    False 0.3183099*l9_amplitude/max(1.e-15, l9_sigma)     None
# l9_sigma              1     0.05        2     None     True     None     None

# %%
### fit and check
fitter.fit()
fitter.plot(show_init=True, numpoints=1000, eval_components=True)

# %%
### plot using current param (before fitting)
fitter.plot_from_params(numpoints=1000, eval_components=True)

# %%
### compare current params and fitted params
### if fitted params are better, overwrite current params
fitter.set_result_param_to_inital()
fitter.params.pretty_print()
fitter.plot_from_params(numpoints=1000, eval_components=True)
# Out:
# Name              Value      Min      Max   Stderr     Vary     Expr Brute_Step
# l0_amplitude      1.829     0.05      inf   0.3626     True     None     None
# l0_center         -10.5      -11      -10        0    False     None     None
# l0_fwhm           2.942     -inf      inf   0.6109    False 2.0000000*l0_sigma     None
# l0_height        0.3958     -inf      inf  0.03398    False 0.3183099*l0_amplitude/max(1.e-15, l0_sigma)     None
# l0_sigma          1.471     0.05        2   0.3055     True     None     None
# l10_amplitude     2.964     0.05      inf    0.227     True     None     None
# l10_center         12.5       12       13        0    False     None     None
# l10_fwhm              4     -inf      inf  0.00319    False 2.0000000*l10_sigma     None
# l10_height       0.4717     -inf      inf  0.03642    False 0.3183099*l10_amplitude/max(1.e-15, l10_sigma)     None
# l10_sigma             2     0.05        2 0.001595     True     None     None
# l1_amplitude      2.056     0.05      inf   0.5145     True     None     None
# l1_center            -7     -7.5     -6.5        0    False     None     None
# l1_fwhm           2.467     -inf      inf   0.3045    False 2.0000000*l1_sigma     None
# l1_height        0.5307     -inf      inf  0.08305    False 0.3183099*l1_amplitude/max(1.e-15, l1_sigma)     None
# l1_sigma          1.233     0.05        2   0.1523     True     None     None
# l2_amplitude     0.8283     0.05      inf   0.6226     True     None     None
# l2_center            -5     -5.5     -4.5        0    False     None     None
# l2_fwhm               4     -inf      inf    1.828    False 2.0000000*l2_sigma     None
# l2_height        0.1318     -inf      inf  0.04314    False 0.3183099*l2_amplitude/max(1.e-15, l2_sigma)     None
# l2_sigma              2     0.05        2   0.9141     True     None     None
# l3_amplitude     0.8283     0.05      inf   0.6226    False l2_amplitude     None
# l3_center            -5     -5.5     -4.5        0    False l2_center     None
# l3_fwhm               4     -inf      inf        0    False 2.0000000*l3_sigma     None
# l3_height        0.1318     -inf      inf        0    False 0.3183099*l3_amplitude/max(1.e-15, l3_sigma)     None
# l3_sigma              2     0.05        2   0.9142    False l2_sigma     None
# l4_amplitude      3.277     0.05      inf    1.417     True     None     None
# l4_center          -1.5       -2       -1        0    False     None     None
# l4_fwhm           3.664     -inf      inf    0.928    False 2.0000000*l4_sigma     None
# l4_height        0.5694     -inf      inf   0.1126    False 0.3183099*l4_amplitude/max(1.e-15, l4_sigma)     None
# l4_sigma          1.832     0.05        2    0.464     True     None     None
# l5_amplitude     0.9811     0.05      inf   0.6573     True     None     None
# l5_center             2      1.5      2.5        0    False     None     None
# l5_fwhm               4     -inf      inf        0    False 2.0000000*l5_sigma     None
# l5_height        0.1561     -inf      inf   0.1046    False 0.3183099*l5_amplitude/max(1.e-15, l5_sigma)     None
# l5_sigma              2     0.05        2   0.9142    False l2_sigma     None
# l6_amplitude     0.9811     0.05      inf   0.6573    False l5_amplitude     None
# l6_center             2      1.5      2.5        0    False l5_center     None
# l6_fwhm               4     -inf      inf        0    False 2.0000000*l6_sigma     None
# l6_height        0.1561     -inf      inf        0    False 0.3183099*l6_amplitude/max(1.e-15, l6_sigma)     None
# l6_sigma              2     0.05        2        0    False l5_sigma     None
# l7_amplitude      2.628     0.05      inf   0.5634     True     None     None
# l7_center           4.5        4        5        0    False     None     None
# l7_fwhm           2.467     -inf      inf        0    False 2.0000000*l7_sigma     None
# l7_height        0.6782     -inf      inf   0.1454    False 0.3183099*l7_amplitude/max(1.e-15, l7_sigma)     None
# l7_sigma          1.233     0.05        2   0.1523    False l1_sigma     None
# l8_amplitude      1.626     0.05      inf   0.3218     True     None     None
# l8_center           7.5        7        8        0    False     None     None
# l8_fwhm           2.503     -inf      inf   0.4786    False 2.0000000*l8_sigma     None
# l8_height        0.4135     -inf      inf  0.03331    False 0.3183099*l8_amplitude/max(1.e-15, l8_sigma)     None
# l8_sigma          1.252     0.05        2   0.2393     True     None     None
# l9_amplitude     0.6655     0.05      inf   0.1858     True     None     None
# l9_center            10      9.5     10.5        0    False     None     None
# l9_fwhm           1.538     -inf      inf   0.4074    False 2.0000000*l9_sigma     None
# l9_height        0.2755     -inf      inf  0.04072    False 0.3183099*l9_amplitude/max(1.e-15, l9_sigma)     None
# l9_sigma          0.769     0.05        2   0.2037     True     None     None

# %%
### set params by hand
## param_name = 'amplitude' or 'sigma' or 'center'
fitter.set_params(i_peak=1, param_name='amplitude', values={'value': 2})
fitter.set_params(i_peak=2, param_name='sigma', values={'value': 0.8})
fitter.set_params(i_peak=2, param_name='amplitude', values={'value': 0.6})
fitter.set_params(i_peak=4, param_name='amplitude', values={'value': 3})
fitter.set_params(i_peak=5, param_name='amplitude', values={'value': 0.7})
fitter.plot_from_params(numpoints=1000, eval_components=True)
# Out:
# revise peaks : [1]
# revise peaks : [2, 3, 5, 6]
# revise peaks : [2, 3]
# revise peaks : [4]
# revise peaks : [5, 6]

# %%
### save
savedir = None
if os.path.isdir(savedir):
    print("'savedir' is already exists")
else:
    fitter.save(savedir)

# %%
### load
fitter2 = fitting.load_fitting(savedir)
fitter2.plot_from_params(numpoints=1000, eval_components=True)

# %%
### output
output_dir = os.getcwd()
i_center = 
header = 'result'
gpifile = 
LO_idx = 
TO_idx = 
elastic_idx = 
    
if os.path.isdir(os.path.join(output_dir, header)):
    print("'output_dir'/result is already exists")
else:    
    fitter2.output(gpifile=gpifile, i_center=i_center, output_dir=output_dir, header='result',
                              LO_idx=LO_idx, TO_idx=TO_idx, elastic_idx=elastic_idx)
# Out:
# set center using peak : 4
# shift is 1.5

# %%
import joblib
hoge = joblib.load("result_summary.pkl")
print(hoge)
# Out:
# {'FileID': 'PbTe_sq_GL711_p0p55_RT_1', 'qx': 7.35, 'qy': 1.35, 'qz': 1.35, 'TO_center': 9.0, 'TO_FWHM': 2.5034726988613554, 'TO_Area': 1.626190200825772, 'LO_center': 3.5, 'LO_FWHM': 3.999965722780324, 'LO_Area': 0.9810771438128045, 'elastic_center': 0.0, 'peak_shift': 1.5}
