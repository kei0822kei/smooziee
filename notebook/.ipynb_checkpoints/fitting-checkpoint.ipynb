# %%
##### setting
### set filename you want to analysis
pkldata = None

if pkldata is None:
    import os
    import smooziee
    pkldata = os.path.join(os.path.dirname(
        os.path.dirname(smooziee.__file__)),
        'data',
        'peak_search.pkl')

# %%
##### import
from smooziee import fitting
from smooziee import peak_search
import os
import imp
import matplotlib.pyplot as plt
imp.reload(fitting)
imp.reload(peak_search)
# Out:
# <module 'smooziee.peak_search' from '/Users/keiyu/Github/smooziee/smooziee/peak_search.py'>

# %%
### show peaksearch result
peak_num = fitting.result_peaksearch(pkldata, return_peak_num=True)
# Out:
# the number of peaks: 11

# %%
### make Fitting class object
fitter = fitting.Fitting(pkldata, ['lorentzian' for i in range(peak_num)])

# %%
print(fitter.i_degenerates)
print(fitter.i_peakpairs)
fitter.params.pretty_print()
# Out:
# [[2, 3], [5, 6]]
# [[1, 7], [2, 5]]
# Name              Value      Min      Max   Stderr     Vary     Expr Brute_Step
# l0_amplitude          1     0.01      inf     None     True     None     None
# l0_center         -10.5      -11      -10     None     True     None     None
# l0_fwhm               2     -inf      inf     None    False 2.0000000*l0_sigma     None
# l0_height        0.3183     -inf      inf     None    False 0.3183099*l0_amplitude/max(1.e-15, l0_sigma)     None
# l0_sigma              1     0.01      inf     None     True     None     None
# l10_amplitude         1     0.01      inf     None     True     None     None
# l10_center         12.5       12       13     None     True     None     None
# l10_fwhm              2     -inf      inf     None    False 2.0000000*l10_sigma     None
# l10_height       0.3183     -inf      inf     None    False 0.3183099*l10_amplitude/max(1.e-15, l10_sigma)     None
# l10_sigma             1     0.01      inf     None     True     None     None
# l1_amplitude          1     0.01      inf     None     True     None     None
# l1_center            -7     -7.5     -6.5     None     True     None     None
# l1_fwhm               2     -inf      inf     None    False 2.0000000*l1_sigma     None
# l1_height        0.3183     -inf      inf     None    False 0.3183099*l1_amplitude/max(1.e-15, l1_sigma)     None
# l1_sigma              1     0.01      inf     None     True     None     None
# l2_amplitude          1     0.01      inf     None     True     None     None
# l2_center            -5     -5.5     -4.5     None     True     None     None
# l2_fwhm               2     -inf      inf     None    False 2.0000000*l2_sigma     None
# l2_height        0.3183     -inf      inf     None    False 0.3183099*l2_amplitude/max(1.e-15, l2_sigma)     None
# l2_sigma              1     0.01      inf     None     True     None     None
# l3_amplitude          1     0.01      inf     None    False l2_amplitude     None
# l3_center            -5     -5.5     -4.5     None    False l2_center     None
# l3_fwhm               2     -inf      inf     None    False 2.0000000*l3_sigma     None
# l3_height        0.3183     -inf      inf     None    False 0.3183099*l3_amplitude/max(1.e-15, l3_sigma)     None
# l3_sigma              1     0.01      inf     None    False l2_sigma     None
# l4_amplitude          1     0.01      inf     None     True     None     None
# l4_center          -1.5       -2       -1     None     True     None     None
# l4_fwhm               2     -inf      inf     None    False 2.0000000*l4_sigma     None
# l4_height        0.3183     -inf      inf     None    False 0.3183099*l4_amplitude/max(1.e-15, l4_sigma)     None
# l4_sigma              1     0.01      inf     None     True     None     None
# l5_amplitude          1     0.01      inf     None     True     None     None
# l5_center             2      1.5      2.5     None     True     None     None
# l5_fwhm               2     -inf      inf     None    False 2.0000000*l5_sigma     None
# l5_height        0.3183     -inf      inf     None    False 0.3183099*l5_amplitude/max(1.e-15, l5_sigma)     None
# l5_sigma              1     0.01      inf     None    False l2_sigma     None
# l6_amplitude          1     0.01      inf     None    False l5_amplitude     None
# l6_center             2      1.5      2.5     None    False l5_center     None
# l6_fwhm               2     -inf      inf     None    False 2.0000000*l6_sigma     None
# l6_height        0.3183     -inf      inf     None    False 0.3183099*l6_amplitude/max(1.e-15, l6_sigma)     None
# l6_sigma              1     0.01      inf     None    False l5_sigma     None
# l7_amplitude          1     0.01      inf     None     True     None     None
# l7_center           4.5        4        5     None     True     None     None
# l7_fwhm               2     -inf      inf     None    False 2.0000000*l7_sigma     None
# l7_height        0.3183     -inf      inf     None    False 0.3183099*l7_amplitude/max(1.e-15, l7_sigma)     None
# l7_sigma              1     0.01      inf     None    False l1_sigma     None
# l8_amplitude          1     0.01      inf     None     True     None     None
# l8_center           7.5        7        8     None     True     None     None
# l8_fwhm               2     -inf      inf     None    False 2.0000000*l8_sigma     None
# l8_height        0.3183     -inf      inf     None    False 0.3183099*l8_amplitude/max(1.e-15, l8_sigma)     None
# l8_sigma              1     0.01      inf     None     True     None     None
# l9_amplitude          1     0.01      inf     None     True     None     None
# l9_center            10      9.5     10.5     None     True     None     None
# l9_fwhm               2     -inf      inf     None    False 2.0000000*l9_sigma     None
# l9_height        0.3183     -inf      inf     None    False 0.3183099*l9_amplitude/max(1.e-15, l9_sigma)     None
# l9_sigma              1     0.01      inf     None     True     None     None

# %%
### set parameters to optimize
## i_peaks -- peak index you want to set
## param_names -- 'amplitude', 'sigma', 'center'
## vary -- True => optimize, False => not optimize
fitter.set_params_vary(i_peaks=list(range(peak_num)), param_names=['center'], vary=False)

# %%
### parameters
fitter.params.pretty_print()
# Out:
# Name              Value      Min      Max   Stderr     Vary     Expr Brute_Step
# l0_amplitude          1    1e-08      inf     None     True     None     None
# l0_center         -10.5     -inf      inf     None    False     None     None
# l0_fwhm               2     -inf      inf     None    False 2.0000000*l0_sigma     None
# l0_height        0.3183     -inf      inf     None    False 0.3183099*l0_amplitude/max(1.e-15, l0_sigma)     None
# l0_sigma              1    1e-08      inf     None     True     None     None
# l10_amplitude         1    1e-08      inf     None     True     None     None
# l10_center         12.5     -inf      inf     None     True     None     None
# l10_fwhm              2     -inf      inf     None    False 2.0000000*l10_sigma     None
# l10_height       0.3183     -inf      inf     None    False 0.3183099*l10_amplitude/max(1.e-15, l10_sigma)     None
# l10_sigma             1    1e-08      inf     None     True     None     None
# l1_amplitude          1    1e-08      inf     None     True     None     None
# l1_center            -7     -inf      inf     None    False     None     None
# l1_fwhm               2     -inf      inf     None    False 2.0000000*l1_sigma     None
# l1_height        0.3183     -inf      inf     None    False 0.3183099*l1_amplitude/max(1.e-15, l1_sigma)     None
# l1_sigma              1    1e-08      inf     None     True     None     None
# l2_amplitude          1    1e-08      inf     None     True     None     None
# l2_center            -5     -inf      inf     None    False     None     None
# l2_fwhm               2     -inf      inf     None    False 2.0000000*l2_sigma     None
# l2_height        0.3183     -inf      inf     None    False 0.3183099*l2_amplitude/max(1.e-15, l2_sigma)     None
# l2_sigma              1    1e-08      inf     None     True     None     None
# l3_amplitude          1    1e-08      inf     None    False l2_amplitude     None
# l3_center            -5     -inf      inf     None    False l2_center     None
# l3_fwhm               2     -inf      inf     None    False 2.0000000*l3_sigma     None
# l3_height        0.3183     -inf      inf     None    False 0.3183099*l3_amplitude/max(1.e-15, l3_sigma)     None
# l3_sigma              1    1e-08      inf     None    False l2_sigma     None
# l4_amplitude          1    1e-08      inf     None     True     None     None
# l4_center          -1.5     -inf      inf     None    False     None     None
# l4_fwhm               2     -inf      inf     None    False 2.0000000*l4_sigma     None
# l4_height        0.3183     -inf      inf     None    False 0.3183099*l4_amplitude/max(1.e-15, l4_sigma)     None
# l4_sigma              1    1e-08      inf     None     True     None     None
# l5_amplitude          1    1e-08      inf     None     True     None     None
# l5_center             2     -inf      inf     None    False     None     None
# l5_fwhm               2     -inf      inf     None    False 2.0000000*l5_sigma     None
# l5_height        0.3183     -inf      inf     None    False 0.3183099*l5_amplitude/max(1.e-15, l5_sigma)     None
# l5_sigma              1    1e-08      inf     None    False l2_sigma     None
# l6_amplitude          1    1e-08      inf     None    False l5_amplitude     None
# l6_center             2     -inf      inf     None    False l5_center     None
# l6_fwhm               2     -inf      inf     None    False 2.0000000*l6_sigma     None
# l6_height        0.3183     -inf      inf     None    False 0.3183099*l6_amplitude/max(1.e-15, l6_sigma)     None
# l6_sigma              1    1e-08      inf     None    False l5_sigma     None
# l7_amplitude          1    1e-08      inf     None     True     None     None
# l7_center           4.5     -inf      inf     None    False     None     None
# l7_fwhm               2     -inf      inf     None    False 2.0000000*l7_sigma     None
# l7_height        0.3183     -inf      inf     None    False 0.3183099*l7_amplitude/max(1.e-15, l7_sigma)     None
# l7_sigma              1    1e-08      inf     None    False l1_sigma     None
# l8_amplitude          1    1e-08      inf     None     True     None     None
# l8_center           7.5     -inf      inf     None    False     None     None
# l8_fwhm               2     -inf      inf     None    False 2.0000000*l8_sigma     None
# l8_height        0.3183     -inf      inf     None    False 0.3183099*l8_amplitude/max(1.e-15, l8_sigma)     None
# l8_sigma              1    1e-08      inf     None     True     None     None
# l9_amplitude          1    1e-08      inf     None     True     None     None
# l9_center            10     -inf      inf     None     True     None     None
# l9_fwhm               2     -inf      inf     None    False 2.0000000*l9_sigma     None
# l9_height        0.3183     -inf      inf     None    False 0.3183099*l9_amplitude/max(1.e-15, l9_sigma)     None
# l9_sigma              1    1e-08      inf     None     True     None     None

# %%
### fit and check
fitter.fit()
fitter.plot(show_init=True, numpoints=1000, eval_components=True)

# %%
### plot using current param (before fitting)
fitter.plot_from_params(numpoints=1000, eval_components=True)

# %%
### compare current params and fitted params
### if fitted params are better, overwrite current params
fitter.set_result_param_to_inital()
fitter.params.pretty_print()
fitter.plot_from_params(numpoints=1000, eval_components=True)
# Out:
# Name              Value      Min      Max   Stderr     Vary     Expr Brute_Step
# l0_amplitude      1.437    1e-08      inf   0.4947     True     None     None
# l0_center         -10.5     -inf      inf        0    False     None     None
# l0_fwhm           2.528     -inf      inf   0.6387    False 2.0000000*l0_sigma     None
# l0_height        0.3618     -inf      inf  0.05225    False 0.3183099*l0_amplitude/max(1.e-15, l0_sigma)     None
# l0_sigma          1.264    1e-08      inf   0.3193     True     None     None
# l10_amplitude     3.697    1e-08      inf   0.5734     True     None     None
# l10_center        12.34     -inf      inf   0.2652     True     None     None
# l10_fwhm          5.515     -inf      inf    0.608    False 2.0000000*l10_sigma     None
# l10_height       0.4267     -inf      inf  0.03027    False 0.3183099*l10_amplitude/max(1.e-15, l10_sigma)     None
# l10_sigma         2.757    1e-08      inf    0.304     True     None     None
# l1_amplitude      1.541    1e-08      inf   0.3546     True     None     None
# l1_center            -7     -inf      inf        0    False     None     None
# l1_fwhm           2.202     -inf      inf   0.2569    False 2.0000000*l1_sigma     None
# l1_height        0.4453     -inf      inf  0.06371    False 0.3183099*l1_amplitude/max(1.e-15, l1_sigma)     None
# l1_sigma          1.101    1e-08      inf   0.1285     True     None     None
# l2_amplitude       1.74    1e-08      inf   0.7467     True     None     None
# l2_center            -5     -inf      inf        0    False     None     None
# l2_fwhm           6.452     -inf      inf    2.157    False 2.0000000*l2_sigma     None
# l2_height        0.1717     -inf      inf  0.02222    False 0.3183099*l2_amplitude/max(1.e-15, l2_sigma)     None
# l2_sigma          3.226    1e-08      inf    1.078     True     None     None
# l3_amplitude       1.74    1e-08      inf   0.7467    False l2_amplitude     None
# l3_center            -5     -inf      inf        0    False l2_center     None
# l3_fwhm           6.452     -inf      inf        0    False 2.0000000*l3_sigma     None
# l3_height        0.1717     -inf      inf        0    False 0.3183099*l3_amplitude/max(1.e-15, l3_sigma)     None
# l3_sigma          3.226    1e-08      inf    1.078    False l2_sigma     None
# l4_amplitude      1.669    1e-08      inf   0.9819     True     None     None
# l4_center          -1.5     -inf      inf        0    False     None     None
# l4_fwhm           2.576     -inf      inf   0.8047    False 2.0000000*l4_sigma     None
# l4_height        0.4125     -inf      inf   0.1224    False 0.3183099*l4_amplitude/max(1.e-15, l4_sigma)     None
# l4_sigma          1.288    1e-08      inf   0.4024     True     None     None
# l5_amplitude      1.889    1e-08      inf   0.7851     True     None     None
# l5_center             2     -inf      inf        0    False     None     None
# l5_fwhm           6.452     -inf      inf        0    False 2.0000000*l5_sigma     None
# l5_height        0.1864     -inf      inf  0.07747    False 0.3183099*l5_amplitude/max(1.e-15, l5_sigma)     None
# l5_sigma          3.226    1e-08      inf    1.078    False l2_sigma     None
# l6_amplitude      1.889    1e-08      inf   0.7851    False l5_amplitude     None
# l6_center             2     -inf      inf        0    False l5_center     None
# l6_fwhm           6.452     -inf      inf        0    False 2.0000000*l6_sigma     None
# l6_height        0.1864     -inf      inf        0    False 0.3183099*l6_amplitude/max(1.e-15, l6_sigma)     None
# l6_sigma          3.226    1e-08      inf        0    False l5_sigma     None
# l7_amplitude      1.983    1e-08      inf   0.4147     True     None     None
# l7_center           4.5     -inf      inf        0    False     None     None
# l7_fwhm           2.202     -inf      inf        0    False 2.0000000*l7_sigma     None
# l7_height        0.5731     -inf      inf   0.1199    False 0.3183099*l7_amplitude/max(1.e-15, l7_sigma)     None
# l7_sigma          1.101    1e-08      inf   0.1285    False l1_sigma     None
# l8_amplitude      1.392    1e-08      inf   0.3271     True     None     None
# l8_center           7.5     -inf      inf        0    False     None     None
# l8_fwhm           2.456     -inf      inf   0.4584    False 2.0000000*l8_sigma     None
# l8_height        0.3607     -inf      inf  0.04173    False 0.3183099*l8_amplitude/max(1.e-15, l8_sigma)     None
# l8_sigma          1.228    1e-08      inf   0.2292     True     None     None
# l9_amplitude     0.3585    1e-08      inf   0.1873     True     None     None
# l9_center         10.16     -inf      inf  0.08885     True     None     None
# l9_fwhm           1.012     -inf      inf   0.4871    False 2.0000000*l9_sigma     None
# l9_height        0.2255     -inf      inf  0.04869    False 0.3183099*l9_amplitude/max(1.e-15, l9_sigma)     None
# l9_sigma         0.5061    1e-08      inf   0.2435     True     None     None

# %%
### set params by hand
## param_name = 'amplitude' or 'sigma' or 'center'
fitter.set_params(i_peak=1, param_name='amplitude', values={'value': 2})
fitter.set_params(i_peak=2, param_name='sigma', values={'value': 0.8})
fitter.set_params(i_peak=2, param_name='amplitude', values={'value': 0.6})
fitter.set_params(i_peak=4, param_name='amplitude', values={'value': 3})
fitter.set_params(i_peak=5, param_name='amplitude', values={'value': 0.7})
fitter.plot_from_params(numpoints=1000, eval_components=True)
# Out:
# revise peaks : [1]
# revise peaks : [2, 3, 5, 6]
# revise peaks : [2, 3]
# revise peaks : [4]
# revise peaks : [5, 6]

# %%
# working dirname 
import os
from IPython.display import display, HTML

js = """<script>IPython.notebook.kernel.execute("file_name=('" + IPython.notebook.notebook_name + "')");</script>"""
display(HTML(js))
dirname = os.path.dirname(os.getcwd())
print(os.getcwd())
# Out:
# <script>IPython.notebook.kernel.execute("file_name=('" + IPython.notebook.notebook_name + "')");</script>
# /Users/keiyu/Github/smooziee/notebook

# %%
### save
savedir = None
if savedir is None:
    savedir = os.path.join(os.path.dirname(os.path.dirname(smooziee.__file__)), 'data', 'fitting_save')
if os.path.isdir(savedir):
    print("'savedir' is already exists")
else:
    fitter.save(savedir)
# Out:
# 'savedir' is already exists

# %%
### load
fitter2 = fitting.load_fitting(savedir)
fitter2.plot_from_params(numpoints=1000, eval_components=True)

# %%
### output
outpur_dir = None
i_center = 4
header = 'result'
gpifile = None

if gpifile is None:
    gpifile = os.path.join(os.path.dirname(os.path.dirname(smooziee.__file__)), 'data', 'gpi.PbTe_sq_GL711_p0p55_RT')
if outpur_dir is None:
    output_dir = os.path.join(os.path.dirname(os.path.dirname(smooziee.__file__)), 'data')
    
if os.path.isdir(os.path.join(output_dir, header)):
    print("'output_dir'/result is already exists")
else:    
    fitter2.output(gpifile=gpifile, i_center=i_center, output_dir=output_dir, header='result')
# Out:
# set center using peak : 4
# shift is 1.5
