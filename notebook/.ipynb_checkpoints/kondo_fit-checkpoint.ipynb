# %%
##### setting
### set filename you want to analysis
pkldata = None

if pkldata == None:
    import os
    import smooziee
    pkldata = os.path.join(os.path.dirname(smooziee.__file__), 'data', 'PbTe_sq_GL711_p0p55_RT_1.pkl')

# %%
##### import
from smooziee.smooziee import fitting
from smooziee.smooziee import peak_search
import imp
import matplotlib.pyplot as plt
imp.reload(fitting)
imp.reload(peak_search)
# Out:
# <module 'smooziee.smooziee.peak_search' from '/home/kondo/git/smooziee/smooziee/peak_search.py'>

# %%
peak_num = fitting.result_peaksearch(pkldata)
# Out:
# the number of peaks: 9

# %%
fitter = fitting.Fitting(pkldata, ['lorentzian' for i in range(peak_num)])

# %%
fitter.set_params_vary(range(peak_num), ['center'], vary=False)

# %%
fitter.params.pretty_print()
# Out:
# Name             Value      Min      Max   Stderr     Vary     Expr Brute_Step
# l0_amplitude         1    1e-08      inf     None     True     None     None
# l0_center        -10.5     -inf      inf     None    False     None     None
# l0_fwhm              2     -inf      inf     None    False 2.0000000*l0_sigma     None
# l0_height       0.3183     -inf      inf     None    False 0.3183099*l0_amplitude/max(1.e-15, l0_sigma)     None
# l0_sigma             1    1e-08      inf     None     True     None     None
# l1_amplitude         1    1e-08      inf     None     True     None     None
# l1_center           -7     -inf      inf     None    False     None     None
# l1_fwhm              2     -inf      inf     None    False 2.0000000*l1_sigma     None
# l1_height       0.3183     -inf      inf     None    False 0.3183099*l1_amplitude/max(1.e-15, l1_sigma)     None
# l1_sigma             1    1e-08      inf     None     True     None     None
# l2_amplitude         1    1e-08      inf     None     True     None     None
# l2_center           -5     -inf      inf     None    False     None     None
# l2_fwhm              2     -inf      inf     None    False 2.0000000*l2_sigma     None
# l2_height       0.3183     -inf      inf     None    False 0.3183099*l2_amplitude/max(1.e-15, l2_sigma)     None
# l2_sigma             1    1e-08      inf     None     True     None     None
# l3_amplitude         1    1e-08      inf     None     True     None     None
# l3_center         -1.5     -inf      inf     None    False     None     None
# l3_fwhm              2     -inf      inf     None    False 2.0000000*l3_sigma     None
# l3_height       0.3183     -inf      inf     None    False 0.3183099*l3_amplitude/max(1.e-15, l3_sigma)     None
# l3_sigma             1    1e-08      inf     None     True     None     None
# l4_amplitude         1    1e-08      inf     None     True     None     None
# l4_center            2     -inf      inf     None    False     None     None
# l4_fwhm              2     -inf      inf     None    False 2.0000000*l4_sigma     None
# l4_height       0.3183     -inf      inf     None    False 0.3183099*l4_amplitude/max(1.e-15, l4_sigma)     None
# l4_sigma             1    1e-08      inf     None    False l2_sigma     None
# l5_amplitude         1    1e-08      inf     None     True     None     None
# l5_center          4.5     -inf      inf     None    False     None     None
# l5_fwhm              2     -inf      inf     None    False 2.0000000*l5_sigma     None
# l5_height       0.3183     -inf      inf     None    False 0.3183099*l5_amplitude/max(1.e-15, l5_sigma)     None
# l5_sigma             1    1e-08      inf     None    False l1_sigma     None
# l6_amplitude         1    1e-08      inf     None     True     None     None
# l6_center          7.5     -inf      inf     None    False     None     None
# l6_fwhm              2     -inf      inf     None    False 2.0000000*l6_sigma     None
# l6_height       0.3183     -inf      inf     None    False 0.3183099*l6_amplitude/max(1.e-15, l6_sigma)     None
# l6_sigma             1    1e-08      inf     None     True     None     None
# l7_amplitude         1    1e-08      inf     None     True     None     None
# l7_center           10     -inf      inf     None    False     None     None
# l7_fwhm              2     -inf      inf     None    False 2.0000000*l7_sigma     None
# l7_height       0.3183     -inf      inf     None    False 0.3183099*l7_amplitude/max(1.e-15, l7_sigma)     None
# l7_sigma             1    1e-08      inf     None     True     None     None
# l8_amplitude         1    1e-08      inf     None     True     None     None
# l8_center         12.5     -inf      inf     None    False     None     None
# l8_fwhm              2     -inf      inf     None    False 2.0000000*l8_sigma     None
# l8_height       0.3183     -inf      inf     None    False 0.3183099*l8_amplitude/max(1.e-15, l8_sigma)     None
# l8_sigma             1    1e-08      inf     None     True     None     None

# %%
fitter.fit()
fitter.set_result_param_to_inital()
fitter.params.pretty_print()
# Out:
# Name             Value      Min      Max   Stderr     Vary     Expr Brute_Step
# l0_amplitude     1.214    1e-08      inf   0.4031     True     None     None
# l0_center        -10.5     -inf      inf        0    False     None     None
# l0_fwhm          2.208     -inf      inf   0.5535    False 2.0000000*l0_sigma     None
# l0_height       0.3501     -inf      inf  0.04921    False 0.3183099*l0_amplitude/max(1.e-15, l0_sigma)     None
# l0_sigma         1.104    1e-08      inf   0.2767     True     None     None
# l1_amplitude     1.544    1e-08      inf   0.3118     True     None     None
# l1_center           -7     -inf      inf        0    False     None     None
# l1_fwhm          2.264     -inf      inf   0.2515    False 2.0000000*l1_sigma     None
# l1_height       0.4343     -inf      inf  0.05341    False 0.3183099*l1_amplitude/max(1.e-15, l1_sigma)     None
# l1_sigma         1.132    1e-08      inf   0.1257     True     None     None
# l2_amplitude      3.88    1e-08      inf    1.274     True     None     None
# l2_center           -5     -inf      inf        0    False     None     None
# l2_fwhm          7.199     -inf      inf    1.954    False 2.0000000*l2_sigma     None
# l2_height       0.3431     -inf      inf  0.03682    False 0.3183099*l2_amplitude/max(1.e-15, l2_sigma)     None
# l2_sigma           3.6    1e-08      inf    0.977     True     None     None
# l3_amplitude     1.441    1e-08      inf    0.737     True     None     None
# l3_center         -1.5     -inf      inf        0    False     None     None
# l3_fwhm          2.417     -inf      inf   0.6908    False 2.0000000*l3_sigma     None
# l3_height       0.3795     -inf      inf  0.09638    False 0.3183099*l3_amplitude/max(1.e-15, l3_sigma)     None
# l3_sigma         1.208    1e-08      inf   0.3454     True     None     None
# l4_amplitude     4.204    1e-08      inf    1.359     True     None     None
# l4_center            2     -inf      inf        0    False     None     None
# l4_fwhm          7.199     -inf      inf        0    False 2.0000000*l4_sigma     None
# l4_height       0.3718     -inf      inf   0.1202    False 0.3183099*l4_amplitude/max(1.e-15, l4_sigma)     None
# l4_sigma           3.6    1e-08      inf    0.977    False l2_sigma     None
# l5_amplitude     2.012    1e-08      inf    0.363     True     None     None
# l5_center          4.5     -inf      inf        0    False     None     None
# l5_fwhm          2.264     -inf      inf        0    False 2.0000000*l5_sigma     None
# l5_height       0.5657     -inf      inf   0.1021    False 0.3183099*l5_amplitude/max(1.e-15, l5_sigma)     None
# l5_sigma         1.132    1e-08      inf   0.1257    False l1_sigma     None
# l6_amplitude      1.18    1e-08      inf   0.2826     True     None     None
# l6_center          7.5     -inf      inf        0    False     None     None
# l6_fwhm          2.143     -inf      inf   0.4118    False 2.0000000*l6_sigma     None
# l6_height       0.3505     -inf      inf  0.04048    False 0.3183099*l6_amplitude/max(1.e-15, l6_sigma)     None
# l6_sigma         1.072    1e-08      inf   0.2059     True     None     None
# l7_amplitude    0.5552    1e-08      inf   0.1386     True     None     None
# l7_center           10     -inf      inf        0    False     None     None
# l7_fwhm          1.524     -inf      inf   0.3889    False 2.0000000*l7_sigma     None
# l7_height       0.2319     -inf      inf  0.03199    False 0.3183099*l7_amplitude/max(1.e-15, l7_sigma)     None
# l7_sigma        0.7622    1e-08      inf   0.1944     True     None     None
# l8_amplitude     3.382    1e-08      inf   0.3792     True     None     None
# l8_center         12.5     -inf      inf        0    False     None     None
# l8_fwhm          5.205     -inf      inf   0.4531    False 2.0000000*l8_sigma     None
# l8_height       0.4136     -inf      inf   0.0261    False 0.3183099*l8_amplitude/max(1.e-15, l8_sigma)     None
# l8_sigma         2.603    1e-08      inf   0.2265     True     None     None

# %%
fitter.plot(show_init=True, eval_components=True)

# %%
fitter.set_params(i_peak=2, param_name='sigma', values={'value': 0.4})
fitter.set_params(i_peak=2, param_name='amplitude', values={'value': 0.1})
fitter.set_params(i_peak=4, param_name='amplitude', values={'value': 0.2})
fitter.plot_from_params(eval_components=True)
# fitter.params.pretty_print()

# %%
fitter.set_params_vary([2, 4], ['sigma', 'amplitude'], vary=False)
fitter.fit()
fitter.set_result_param_to_inital()
fitter.plot(show_init=True, eval_components=True)

# %%
fitter.fit()
fitter.set_result_param_to_inital()
fitter.plot(show_init=True, eval_components=True)

# %%
fitter.set_params_vary(i_peaks=range(peak_num),
                       param_names=['sigma', 'amplitude', 'center'],
                       vary=True)
fitter.fit()
fitter.set_result_param_to_inital()
fitter.params.pretty_print()
# Out:
# Name             Value      Min      Max   Stderr     Vary     Expr Brute_Step
# l0_amplitude     72.58    1e-08      inf 7.234e+04     True     None     None
# l0_center       -12.98     -inf      inf    9.265     True     None     None
# l0_fwhm          0.226     -inf      inf    226.2    False 2.0000000*l0_sigma     None
# l0_height        204.4     -inf      inf 4.084e+05    False 0.3183099*l0_amplitude/max(1.e-15, l0_sigma)     None
# l0_sigma         0.113    1e-08      inf    113.1     True     None     None
# l1_amplitude     2.724    1e-08      inf   0.4776     True     None     None
# l1_center       -6.894     -inf      inf  0.07298     True     None     None
# l1_fwhm          2.958     -inf      inf   0.2597    False 2.0000000*l1_sigma     None
# l1_height       0.5863     -inf      inf  0.06634    False 0.3183099*l1_amplitude/max(1.e-15, l1_sigma)     None
# l1_sigma         1.479    1e-08      inf   0.1298     True     None     None
# l2_amplitude    0.1336    1e-08      inf  0.07005     True     None     None
# l2_center       -4.746     -inf      inf  0.09092     True     None     None
# l2_fwhm         0.6739     -inf      inf   0.4757    False 2.0000000*l2_sigma     None
# l2_height       0.1262     -inf      inf  0.06134    False 0.3183099*l2_amplitude/max(1.e-15, l2_sigma)     None
# l2_sigma         0.337    1e-08      inf   0.2378     True     None     None
# l3_amplitude     5.192    1e-08      inf   0.5784     True     None     None
# l3_center       -1.549     -inf      inf   0.0823     True     None     None
# l3_fwhm          5.154     -inf      inf   0.4832    False 2.0000000*l3_sigma     None
# l3_height       0.6413     -inf      inf  0.03103    False 0.3183099*l3_amplitude/max(1.e-15, l3_sigma)     None
# l3_sigma         2.577    1e-08      inf   0.2416     True     None     None
# l4_amplitude    0.2432    1e-08      inf   0.1037     True     None     None
# l4_center        1.843     -inf      inf  0.09339     True     None     None
# l4_fwhm         0.6739     -inf      inf        0    False 2.0000000*l4_sigma     None
# l4_height       0.2297     -inf      inf    0.098    False 0.3183099*l4_amplitude/max(1.e-15, l4_sigma)     None
# l4_sigma         0.337    1e-08      inf   0.2378    False l2_sigma     None
# l5_amplitude      3.44    1e-08      inf   0.3368     True     None     None
# l5_center         4.29     -inf      inf  0.05449     True     None     None
# l5_fwhm          2.958     -inf      inf        0    False 2.0000000*l5_sigma     None
# l5_height       0.7403     -inf      inf  0.07247    False 0.3183099*l5_amplitude/max(1.e-15, l5_sigma)     None
# l5_sigma         1.479    1e-08      inf   0.1298    False l1_sigma     None
# l6_amplitude     1.423    1e-08      inf   0.2784     True     None     None
# l6_center        7.638     -inf      inf  0.09272     True     None     None
# l6_fwhm          2.459     -inf      inf   0.4312    False 2.0000000*l6_sigma     None
# l6_height       0.3683     -inf      inf  0.02959    False 0.3183099*l6_amplitude/max(1.e-15, l6_sigma)     None
# l6_sigma          1.23    1e-08      inf   0.2156     True     None     None
# l7_amplitude     0.319    1e-08      inf   0.1535     True     None     None
# l7_center        10.18     -inf      inf  0.07056     True     None     None
# l7_fwhm         0.8534     -inf      inf   0.4777    False 2.0000000*l7_sigma     None
# l7_height        0.238     -inf      inf  0.05431    False 0.3183099*l7_amplitude/max(1.e-15, l7_sigma)     None
# l7_sigma        0.4267    1e-08      inf   0.2389     True     None     None
# l8_amplitude     3.809    1e-08      inf   0.4203     True     None     None
# l8_center        12.34     -inf      inf   0.2296     True     None     None
# l8_fwhm          5.557     -inf      inf   0.4978    False 2.0000000*l8_sigma     None
# l8_height       0.4363     -inf      inf  0.02081    False 0.3183099*l8_amplitude/max(1.e-15, l8_sigma)     None
# l8_sigma         2.779    1e-08      inf   0.2489     True     None     None

# %%
fitter.plot(show_init=True, eval_components=True)
# type(fitter.result)
