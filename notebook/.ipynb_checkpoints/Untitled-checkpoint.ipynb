# %%
import sys
import imp
sys.path.append("/Users/keiyu/Github/smooziee/module")
import phonon_scattering as ph_scat
imp.reload(ph_scat)
import matplotlib.pyplot as plt

# %%
### experimental file name
filename = "/Users/keiyu/Github/smooziee/example/KCl_GXL511_m0p25_RT_4"

# %%
### initial plot
data = ph_scat.Process(filename)
fig = plt.figure()
ax = fig.add_subplot(111)
data.plot(ax)
plt.show()

# %%
### find peak
# varialbes
order = 10 

# main
fig = plt.figure()
ax = fig.add_subplot(111)
data.find_peak(order=order)
data.plot(ax)
plt.show()
# Out:
# found 5 peaks

# %%
### find peak pair
# varialbes
order = 10
threshold = 10

# main
data = ph_scat.Process(filename)
fig = plt.figure()
ax = fig.add_subplot(111)
data.find_peak(order=order)
data.find_peak_pair(threshold=threshold)
data.plot(ax)
plt.show()
# Out:
# found 5 peaks
# found 2 pair

# %%
### initial fit
# varivable
order = 10
threshold = 10
idx_range = 10

# main
fig = plt.figure()
ax = fig.add_subplot(111)
data.find_peak(order=order)
data.find_peak_pair(threshold=threshold)
data.initial_fit(idx_range=idx_range)
data.plot(ax)
plt.show()
# Out:
# found 5 peaks
# found 2 pair
# make initial fitting

# %%
### make grid parameter
# varivable
order = 10
threshold = 10
idx_range = 10
grid_param = {'A':[3, 0.02], 'x0':[1, 0.5], 'd':[3, 0.02]}

# main
data.find_peak(order=order)
data.find_peak_pair(threshold=threshold)
data.initial_fit(idx_range=idx_range)
data.make_grid_param(grid_param)
# Out:
# found 5 peaks
# found 2 pair
# make initial fitting
# total grid parameter is 59049
# initial param num is 59049
# if not the same d value between the pairs, remove from param_lst
# final param num is 6561

# %%
### make grid parameter
# varivable
order = 10
threshold = 10
idx_range = 10
grid_param = {'A':[3, 0.02], 'x0':[1, 0.5], 'd':[3, 0.02]}

# main
fig = plt.figure()
ax = fig.add_subplot(111)
data.find_peak(order=order)
data.find_peak_pair(threshold=threshold)
data.initial_fit(idx_range=idx_range)
data.make_grid_param(grid_param)
data.grid_search()
data.plot(ax)
plt.show()
# Out:
# found 5 peaks
# found 2 pair
# make initial fitting
# total grid parameter is 59049
# initial param num is 59049
# if not the same d value between the pairs, remove from param_lst
# final param num is 6561
# best score was 0.000350793049168
# best param was set to self.best_param_lst

# %%
# Out:
# [[0.021623592292539653, -22.049305243312212, 6.6672639365383954],
#  [0.07794153559421689, -16.026496693879988, 1.2668483321549606],
#  [1.0707745092102787, 1.1103935658649193, 0.96052638453036199],
#  [0.19983821016959413, 18.699920257572277, 1.2668483321549606],
#  [0.043208409966998901, 26.464352972518366, 6.6672639365383954]]
